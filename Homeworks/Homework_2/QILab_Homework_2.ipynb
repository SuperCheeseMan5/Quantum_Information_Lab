# %% [markdown]
# <h2> <center> Homework 2 </center> </h2>
# <pre><center>    PHYS:4340L                    Matthew Jarek</center></pre>

# %% [markdown]
# _________

# %% [markdown]
# <p><b>Job ID</b>: d61oga3c4tus73fch7f0</p>
# <h4>Methods</h4>
# <p>The <b>X-gate</b> is another name for the <b>NOT</b> gate. To create an X-gate circuit, the NOT gate needs to be put on q[0] with the measure gate following.</p>
# <p align = center><img src="images/Homework_2_Gate.png", style="max-width:800px;width:100%"></p>
# <p> This configuration will theoretically result in a 100% probability of measuring the |1&rangle; state which can be seen the the probabilites plot below.
# <p align = center><img src="images/Homework_2_theory_probabilities.png", style="max-width:800px;width:100%"></p>
#
# <h4>Results</h4>
# <p>After running the circuit <b>(1024 shots)</b> we get interesting results. </p>
# <p align = center><img src="images/Homework_2_theory_probabilities.png", style="max-width:800px;width:100%"></p>
# <p> While most of the resulting outcomes are in |1&rangle;, 139/1024, or about 13.5% of the measuremnts remained in |0&rangle; .
# <!-- <p><img src="images/Homework_2_x_gate.png"></p> -->
